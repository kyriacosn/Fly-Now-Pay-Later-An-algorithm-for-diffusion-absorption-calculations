# %%
from analysis import simulation_analysis
import numpy as np

# %%
simulation =  simulation_analysis("")

opt = simulation.slsqp_optimize(1,1*np.ones(32))

mesh_boundaries = np.array(simulation.settings["mesh"])

mid_points = (mesh_boundaries[1:] + mesh_boundaries[0:-1])/2

plt.plot(mid_points,opt.x)

# %%
mid_points
# Out:
# array([0.1084145, 0.0811105, 0.070789 , 0.0648275, 0.0608405, 0.057962 ,
#        0.055789 , 0.054102 , 0.0527715, 0.0517155, 0.050879 , 0.0502245,
#        0.049726 , 0.0493665, 0.049132 , 0.0490175, 0.0490175, 0.049132 ,
#        0.0493665, 0.049726 , 0.0502245, 0.050879 , 0.0517155, 0.0527715,
#        0.054102 , 0.055789 , 0.057962 , 0.0608405, 0.0648275, 0.070789 ,
#        0.0811105, 0.1084145])
